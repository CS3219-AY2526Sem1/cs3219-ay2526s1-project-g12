# %% [markdown]
# ## Import tool for qns-svc

# %% [markdown]
# Dataset is taken from:
# - https://arxiv.org/abs/2504.14655
# - https://github.com/newfacade/LeetCodeDataset/tree/main
# - https://huggingface.co/datasets/newfacade/LeetCodeDataset

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import requests

# %%
QNS_SVC_URL="http://127.0.0.1:8000"

# %%
# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'train': 'LeetCodeDataset-train.jsonl', 'test': 'LeetCodeDataset-test.jsonl'}
lc_df = pd.read_json("hf://datasets/newfacade/LeetCodeDataset/" + splits["train"], lines=True)

# %%
lc_df.head(2)
# Out:
#            task_id  question_id difficulty                            tags  \
# 0          two-sum            1       Easy             [Array, Hash Table]
# 1  add-two-numbers            2     Medium  [Recursion, Linked List, Math]
#
#                                  problem_description  \
# 0  Given an array of integers nums and an integer...
# 1  You are given two non-empty linked lists repre...
#
#                                         starter_code estimated_date  \
# 0  class Solution:\n    def twoSum(self, nums: Li...     2015-08-07
# 1  # Definition for singly-linked list.\n# class ...     2015-08-07
#
#                                               prompt  \
# 0  import random\nimport functools\nimport collec...
# 1  import heapq\nimport itertools\nfrom sortedcon...
#
#                                           completion  \
# 0  class Solution:\n    def twoSum(self, nums: Li...
# 1  # Definition for singly-linked list.\n# class ...
#
#                 entry_point  \
# 0         Solution().twoSum
# 1  Solution().addTwoNumbers
#
#                                                 test  \
# 0  def check(candidate):\n    assert candidate(nu...
# 1  def check(candidate):\n    assert is_same_list...
#
#                                         input_output  \
# 0  [{'input': 'nums = [3,3], target = 6', 'output...
# 1  [{'input': 'l1 = [9,8,7], l2 = [1,2,3]', 'outp...
#
#                                                query  \
# 0  You are an expert Python programmer. You will ...
# 1  You are an expert Python programmer. You will ...
#
#                                             response
# 0  To solve this problem efficiently, we can use ...
# 1  ```python\n# Definition for singly-linked list...

# %% [markdown]
# #### Process Difficulty

# %%
unique_difficulties = list(set(lc_df['difficulty']))
unique_difficulties
# Out:
# ['Easy', 'Hard', 'Medium']

# %%
for difficulty in unique_difficulties:
    res = requests.post(f"{QNS_SVC_URL}/difficulty", json={"level": difficulty})
    print(res.json())
# Out:
# {'message': 'Difficulty level Easy created successfully'}
# {'message': 'Difficulty level Hard created successfully'}
# {'message': 'Difficulty level Medium created successfully'}

# %% [markdown]
# ### Process Categories

# %%
unique_categories = list(set(lc_df['tags'].sum()))
unique_categories
# Out:
# ['Array',
#  'Breadth-First Search',
#  'Hash Table',
#  'Bucket Sort',
#  'Line Sweep',
#  'Eulerian Circuit',
#  'Stack',
#  'Probability and Statistics',
#  'Rolling Hash',
#  'String',
#  'Quickselect',
#  'Depth-First Search',
#  'Number Theory',
#  'Sliding Window',
#  'Bit Manipulation',
#  'Binary Tree',
#  'Recursion',
#  'Strongly Connected Component',
#  'Hash Function',
#  'Greedy',
#  'Union Find',
#  'Binary Search Tree',
#  'Geometry',
#  'Tree',
#  'Two Pointers',
#  'Segment Tree',
#  'Monotonic Queue',
#  'Brainteaser',
#  'Merge Sort',
#  'Game Theory',
#  'Simulation',
#  'Ordered Set',
#  'Counting Sort',
#  'Randomized',
#  'Matrix',
#  'Math',
#  'Monotonic Stack',
#  'Heap (Priority Queue)',
#  'Interactive',
#  'Combinatorics',
#  'Suffix Array',
#  'Prefix Sum',
#  'Binary Search',
#  'String Matching',
#  'Radix Sort',
#  'Enumeration',
#  'Biconnected Component',
#  'Minimum Spanning Tree',
#  'Queue',
#  'Backtracking',
#  'Graph',
#  'Bitmask',
#  'Concurrency',
#  'Counting',
#  'Topological Sort',
#  'Shortest Path',
#  'Dynamic Programming',
#  'Divide and Conquer',
#  'Memoization',
#  'Sorting',
#  'Linked List',
#  'Binary Indexed Tree',
#  'Trie']

# %%
success_imported_cat = []
failure_imported_cat = []
for cat in unique_categories:
    res = requests.post(f"{QNS_SVC_URL}/category", json={"name": cat})
    if res.ok:
        success_imported_cat.append(cat)
    else:
        failure_imported_cat.append(cat)

print(success_imported_cat)
print(failure_imported_cat)
# Out:
# ['Array', 'Breadth-First Search', 'Hash Table', 'Bucket Sort', 'Line Sweep', 'Eulerian Circuit', 'Stack', 'Probability and Statistics', 'Rolling Hash', 'String', 'Quickselect', 'Depth-First Search', 'Number Theory', 'Sliding Window', 'Bit Manipulation', 'Binary Tree', 'Recursion', 'Strongly Connected Component', 'Hash Function', 'Greedy', 'Union Find', 'Binary Search Tree', 'Geometry', 'Tree', 'Two Pointers', 'Segment Tree', 'Monotonic Queue', 'Brainteaser', 'Merge Sort', 'Game Theory', 'Simulation', 'Ordered Set', 'Counting Sort', 'Randomized', 'Matrix', 'Math', 'Monotonic Stack', 'Heap (Priority Queue)', 'Interactive', 'Combinatorics', 'Suffix Array', 'Prefix Sum', 'Binary Search', 'String Matching', 'Radix Sort', 'Enumeration', 'Biconnected Component', 'Minimum Spanning Tree', 'Queue', 'Backtracking', 'Graph', 'Bitmask', 'Concurrency', 'Counting', 'Topological Sort', 'Shortest Path', 'Dynamic Programming', 'Divide and Conquer', 'Memoization', 'Sorting', 'Linked List', 'Binary Indexed Tree', 'Trie']
# []

# %% [markdown]
# ### Process Questions

# %%
lc_df.columns
# Out:
# Index(['task_id', 'question_id', 'difficulty', 'tags', 'problem_description',
#        'starter_code', 'estimated_date', 'prompt', 'completion', 'entry_point',
#        'test', 'input_output', 'query', 'response'],
#       dtype='object')

# %%
failure_imported_qns = []

for index, row in lc_df.iterrows():
    qns_payload = {
        "title": row['task_id'],
        "description": row['problem_description'],
        "difficulty": row['difficulty'],
        "categories": row['tags'],
        "code_template": row['starter_code'],
        "solution_sample": row['completion']
    }
    print(f"{index}: {row['task_id']}")
    res = requests.post(f"{QNS_SVC_URL}/questions/", json=qns_payload)
    if not res.ok:
        failure_imported_qns.append((index, row['task_id']))

print(failure_imported_qns)
# Out:
# 0: two-sum
# 1: add-two-numbers
# 2: longest-substring-without-repeating-characters
# 3: median-of-two-sorted-arrays
# 4: longest-palindromic-substring
# 5: zigzag-conversion
# 6: reverse-integer
# 7: string-to-integer-atoi
# 8: palindrome-number
# 9: regular-expression-matching
# 10: container-with-most-water
# 11: integer-to-roman
# 12: roman-to-integer
# 13: longest-common-prefix
# 14: 3sum
# 15: 3sum-closest
# 16: letter-combinations-of-a-phone-number
# 17: 4sum
# 18: remove-nth-node-from-end-of-list
# 19: valid-parentheses
# 20: merge-two-sorted-lists
# 21: generate-parentheses
# 22: merge-k-sorted-lists
# 23: swap-nodes-in-pairs
# 24: reverse-nodes-in-k-group
# 25: remove-duplicates-from-sorted-array
# 26: remove-element
# 27: find-the-index-of-the-first-occurrence-in-a-string
# 28: divide-two-integers
# 29: substring-with-concatenation-of-all-words
# 30: next-permutation
# 31: longest-valid-parentheses
# 32: search-in-rotated-sorted-array
# 33: find-first-and-last-position-of-element-in-sorted-array
# 34: search-insert-position
# 35: valid-sudoku
# 36: sudoku-solver
# 37: count-and-say
# 38: combination-sum
# 39: combination-sum-ii
# 40: first-missing-positive
# 41: trapping-rain-water
# 42: multiply-strings
# 43: wildcard-matching
# 44: jump-game-ii
# 45: permutations
# 46: permutations-ii
# 47: rotate-image
# 48: group-anagrams
# 49: powx-n
# 50: n-queens
# 51: n-queens-ii
# 52: maximum-subarray
# 53: spiral-matrix
# 54: jump-game
# 55: merge-intervals
# 56: insert-interval
# 57: length-of-last-word
# 58: spiral-matrix-ii
# 59: permutation-sequence
# 60: rotate-list
# 61: unique-paths
# 62: unique-paths-ii
# 63: minimum-path-sum
# 64: valid-number
# 65: plus-one
# 66: add-binary
# 67: text-justification
# 68: sqrtx
# 69: climbing-stairs
# 70: simplify-path
# 71: edit-distance
# 72: set-matrix-zeroes
# 73: search-a-2d-matrix
# 74: sort-colors
# 75: minimum-window-substring
# 76: combinations
# 77: subsets
# 78: word-search
# 79: remove-duplicates-from-sorted-array-ii
# 80: search-in-rotated-sorted-array-ii
# 81: remove-duplicates-from-sorted-list-ii
# 82: remove-duplicates-from-sorted-list
# 83: largest-rectangle-in-histogram
# 84: maximal-rectangle
# 85: partition-list
# 86: scramble-string
# 87: merge-sorted-array
# 88: gray-code
# 89: subsets-ii
# 90: decode-ways
# 91: reverse-linked-list-ii
# 92: restore-ip-addresses
# 93: binary-tree-inorder-traversal
# 94: unique-binary-search-trees
# 95: interleaving-string
# 96: validate-binary-search-tree
# 97: recover-binary-search-tree
# 98: same-tree
# 99: symmetric-tree
# 100: binary-tree-level-order-traversal
# 101: binary-tree-zigzag-level-order-traversal
# 102: maximum-depth-of-binary-tree
# 103: construct-binary-tree-from-preorder-and-inorder-traversal
# 104: construct-binary-tree-from-inorder-and-postorder-traversal
# 105: binary-tree-level-order-traversal-ii
# 106: convert-sorted-array-to-binary-search-tree
# 107: convert-sorted-list-to-binary-search-tree
# 108: balanced-binary-tree
# 109: minimum-depth-of-binary-tree
# 110: path-sum
# 111: path-sum-ii
# 112: flatten-binary-tree-to-linked-list
# 113: distinct-subsequences
# 114: pascals-triangle
# 115: pascals-triangle-ii
# 116: triangle
# 117: best-time-to-buy-and-sell-stock
# 118: best-time-to-buy-and-sell-stock-ii
# 119: best-time-to-buy-and-sell-stock-iii
# 120: binary-tree-maximum-path-sum
# 121: valid-palindrome
# 122: word-ladder
# 123: longest-consecutive-sequence
# 124: sum-root-to-leaf-numbers
# 125: surrounded-regions
# 126: palindrome-partitioning
# 127: palindrome-partitioning-ii
# 128: gas-station
# 129: candy
# 130: single-number
# 131: single-number-ii
# 132: word-break
# 133: word-break-ii
# 134: linked-list-cycle
# 135: reorder-list
# 136: binary-tree-preorder-traversal
# 137: binary-tree-postorder-traversal
# 138: insertion-sort-list
# 139: sort-list
# 140: max-points-on-a-line
# 141: evaluate-reverse-polish-notation
# 142: reverse-words-in-a-string
# 143: maximum-product-subarray
# 144: find-minimum-in-rotated-sorted-array
# 145: find-minimum-in-rotated-sorted-array-ii
# 146: binary-tree-upside-down
# 147: longest-substring-with-at-most-two-distinct-characters
# 148: intersection-of-two-linked-lists
# 149: one-edit-distance
# 150: find-peak-element
# 151: missing-ranges
# 152: maximum-gap
# 153: compare-version-numbers
# 154: fraction-to-recurring-decimal
# 155: two-sum-ii-input-array-is-sorted
# 156: excel-sheet-column-title
# 157: majority-element
# 158: excel-sheet-column-number
# 159: factorial-trailing-zeroes
# 160: dungeon-game
# 161: largest-number
# 162: reverse-words-in-a-string-ii
# 163: repeated-dna-sequences
# 164: best-time-to-buy-and-sell-stock-iv
# 165: rotate-array
# 166: reverse-bits
# 167: number-of-1-bits
# 168: house-robber
# 169: binary-tree-right-side-view
# 170: number-of-islands
# 171: bitwise-and-of-numbers-range
# 172: happy-number
# 173: remove-linked-list-elements
# 174: count-primes
# 175: isomorphic-strings
# 176: reverse-linked-list
# 177: course-schedule
# 178: minimum-size-subarray-sum
# 179: course-schedule-ii
# 180: word-search-ii
# 181: house-robber-ii
# 182: shortest-palindrome
# 183: kth-largest-element-in-an-array
# 184: combination-sum-iii
# 185: contains-duplicate
# 186: the-skyline-problem
# 187: contains-duplicate-ii
# 188: contains-duplicate-iii
# 189: maximal-square
# 190: count-complete-tree-nodes
# 191: rectangle-area
# 192: basic-calculator
# 193: invert-binary-tree
# 194: basic-calculator-ii
# 195: summary-ranges
# 196: majority-element-ii
# 197: kth-smallest-element-in-a-bst
# 198: power-of-two
# 199: number-of-digit-one
# 200: palindrome-linked-list
# 201: lowest-common-ancestor-of-a-binary-tree
# 202: product-of-array-except-self
# 203: sliding-window-maximum
# 204: search-a-2d-matrix-ii
# 205: different-ways-to-add-parentheses
# 206: valid-anagram
# 207: shortest-word-distance
# 208: shortest-word-distance-iii
# 209: strobogrammatic-number
# 210: strobogrammatic-number-ii
# 211: strobogrammatic-number-iii
# 212: group-shifted-strings
# 213: count-univalue-subtrees
# 214: meeting-rooms
# 215: meeting-rooms-ii
# 216: factor-combinations
# 217: verify-preorder-sequence-in-binary-search-tree
# 218: paint-house
# 219: binary-tree-paths
# 220: add-digits
# 221: 3sum-smaller
# 222: single-number-iii
# 223: graph-valid-tree
# 224: ugly-number
# 225: ugly-number-ii
# 226: paint-house-ii
# 227: palindrome-permutation
# 228: palindrome-permutation-ii
# 229: missing-number
# 230: alien-dictionary
# 231: closest-binary-search-tree-value
# 232: closest-binary-search-tree-value-ii
# 233: integer-to-english-words
# 234: h-index
# 235: h-index-ii
# 236: paint-fence
# 237: first-bad-version
# 238: perfect-squares
# 239: wiggle-sort
# 240: expression-add-operators
# 241: move-zeroes
# 242: walls-and-gates
# 243: find-the-duplicate-number
# 244: game-of-life
# 245: word-pattern
# 246: word-pattern-ii
# 247: nim-game
# 248: flip-game
# 249: flip-game-ii
# 250: best-meeting-point
# 251: binary-tree-longest-consecutive-sequence
# 252: bulls-and-cows
# 253: longest-increasing-subsequence
# 254: smallest-rectangle-enclosing-black-pixels
# 255: number-of-islands-ii
# 256: additive-number
# 257: best-time-to-buy-and-sell-stock-with-cooldown
# 258: minimum-height-trees
# 259: sparse-matrix-multiplication
# 260: burst-balloons
# 261: super-ugly-number
# 262: binary-tree-vertical-order-traversal
# 263: count-of-smaller-numbers-after-self
# 264: remove-duplicate-letters
# 265: shortest-distance-from-all-buildings
# 266: maximum-product-of-word-lengths
# 267: bulb-switcher
# 268: generalized-abbreviation
# 269: create-maximum-number
# 270: coin-change
# 271: number-of-connected-components-in-an-undirected-graph
# 272: wiggle-sort-ii
# 273: maximum-size-subarray-sum-equals-k
# 274: power-of-three
# 275: count-of-range-sum
# 276: odd-even-linked-list
# 277: longest-increasing-path-in-a-matrix
# 278: patching-array
# 279: verify-preorder-serialization-of-a-binary-tree
# 280: reconstruct-itinerary
# 281: largest-bst-subtree
# 282: increasing-triplet-subsequence
# 283: self-crossing
# 284: palindrome-pairs
# 285: house-robber-iii
# 286: counting-bits
# 287: longest-substring-with-at-most-k-distinct-characters
# 288: power-of-four
# 289: integer-break
# 290: reverse-string
# 291: reverse-vowels-of-a-string
# 292: top-k-frequent-elements
# 293: intersection-of-two-arrays
# 294: intersection-of-two-arrays-ii
# 295: android-unlock-patterns
# 296: russian-doll-envelopes
# 297: line-reflection
# 298: count-numbers-with-unique-digits
# 299: rearrange-string-k-distance-apart
# 300: sort-transformed-array
# 301: bomb-enemy
# 302: max-sum-of-rectangle-no-larger-than-k
# 303: water-and-jug-problem
# 304: find-leaves-of-binary-tree
# 305: valid-perfect-square
# 306: largest-divisible-subset
# 307: plus-one-linked-list
# 308: range-addition
# 309: sum-of-two-integers
# 310: find-k-pairs-with-smallest-sums
# 311: guess-number-higher-or-lower-ii
# 312: wiggle-subsequence
# 313: combination-sum-iv
# 314: kth-smallest-element-in-a-sorted-matrix
# 315: ransom-note
# 316: lexicographical-numbers
# 317: first-unique-character-in-a-string
# 318: longest-absolute-file-path
# 319: find-the-difference
# 320: elimination-game
# 321: perfect-rectangle
# 322: is-subsequence
# 323: utf-8-validation
# 324: decode-string
# 325: longest-substring-with-at-least-k-repeating-characters
# 326: rotate-function
# 327: integer-replacement
# 328: evaluate-division
# 329: nth-digit
# 330: binary-watch
# 331: remove-k-digits
# 332: frog-jump
# 333: sum-of-left-leaves
# 334: convert-a-number-to-hexadecimal
# 335: queue-reconstruction-by-height
# 336: trapping-rain-water-ii
# 337: valid-word-abbreviation
# 338: longest-palindrome
# 339: split-array-largest-sum
# 340: minimum-unique-word-abbreviation
# 341: fizz-buzz
# 342: arithmetic-slices
# 343: third-maximum-number
# 344: add-strings
# 345: partition-equal-subset-sum
# 346: pacific-atlantic-water-flow
# 347: sentence-screen-fitting
# 348: battleships-in-a-board
# 349: strong-password-checker
# 350: maximum-xor-of-two-numbers-in-an-array
# 351: valid-word-square
# 352: reconstruct-original-digits-from-english
# 353: longest-repeating-character-replacement
# 354: word-squares
# 355: minimum-genetic-mutation
# 356: number-of-segments-in-a-string
# 357: non-overlapping-intervals
# 358: find-right-interval
# 359: path-sum-iii
# 360: find-all-anagrams-in-a-string
# 361: ternary-expression-parser
# 362: k-th-smallest-in-lexicographical-order
# 363: arranging-coins
# 364: find-all-duplicates-in-an-array
# 365: string-compression
# 366: sequence-reconstruction
# 367: add-two-numbers-ii
# 368: arithmetic-slices-ii-subsequence
# 369: number-of-boomerangs
# 370: find-all-numbers-disappeared-in-an-array
# 371: delete-node-in-a-bst
# 372: sort-characters-by-frequency
# 373: minimum-number-of-arrows-to-burst-balloons
# 374: minimum-moves-to-equal-array-elements
# 375: 4sum-ii
# 376: assign-cookies
# 377: 132-pattern
# 378: circular-array-loop
# 379: poor-pigs
# 380: repeated-substring-pattern
# 381: hamming-distance
# 382: minimum-moves-to-equal-array-elements-ii
# 383: island-perimeter
# 384: can-i-win
# 385: optimal-account-balancing
# 386: count-the-repetitions
# 387: unique-substrings-in-wraparound-string
# 388: validate-ip-address
# 389: convex-polygon
# 390: encode-string-with-shortest-length
# 391: concatenated-words
# 392: matchsticks-to-square
# 393: ones-and-zeroes
# 394: heaters
# 395: number-complement
# 396: total-hamming-distance
# 397: largest-palindrome-product
# 398: sliding-window-median
# 399: magical-string
# 400: license-key-formatting
# 401: smallest-good-base
# 402: find-permutation
# 403: max-consecutive-ones
# 404: predict-the-winner
# 405: max-consecutive-ones-ii
# 406: zuma-game
# 407: the-maze
# 408: non-decreasing-subsequences
# 409: construct-the-rectangle
# 410: reverse-pairs
# 411: target-sum
# 412: teemo-attacking
# 413: next-greater-element-i
# 414: diagonal-traverse
# 415: the-maze-iii
# 416: keyboard-row
# 417: find-mode-in-binary-search-tree
# 418: ipo
# 419: next-greater-element-ii
# 420: base-7
# 421: the-maze-ii
# 422: relative-ranks
# 423: perfect-number
# 424: most-frequent-subtree-sum
# 425: fibonacci-number
# 426: find-bottom-left-tree-value
# 427: freedom-trail
# 428: find-largest-value-in-each-tree-row
# 429: longest-palindromic-subsequence
# 430: super-washing-machines
# 431: coin-change-ii
# 432: detect-capital
# 433: longest-uncommon-subsequence-i
# 434: longest-uncommon-subsequence-ii
# 435: continuous-subarray-sum
# 436: longest-word-in-dictionary-through-deleting
# 437: contiguous-array
# 438: beautiful-arrangement
# 439: word-abbreviation
# 440: minesweeper
# 441: minimum-absolute-difference-in-bst
# 442: lonely-pixel-i
# 443: k-diff-pairs-in-an-array
# 444: lonely-pixel-ii
# 445: construct-binary-tree-from-string
# 446: complex-number-multiplication
# 447: convert-bst-to-greater-tree
# 448: minimum-time-difference
# 449: single-element-in-a-sorted-array
# 450: reverse-string-ii
# 451: 01-matrix
# 452: diameter-of-binary-tree
# 453: output-contest-matches
# 454: boundary-of-binary-tree
# 455: remove-boxes
# 456: number-of-provinces
# 457: split-array-with-equal-sum
# 458: binary-tree-longest-consecutive-sequence-ii
# 459: student-attendance-record-i
# 460: student-attendance-record-ii
# 461: optimal-division
# 462: brick-wall
# 463: split-concatenated-strings
# 464: next-greater-element-iii
# 465: reverse-words-in-a-string-iii
# 466: subarray-sum-equals-k
# 467: array-partition
# 468: longest-line-of-consecutive-one-in-matrix
# 469: binary-tree-tilt
# 470: find-the-closest-palindrome
# 471: array-nesting
# 472: reshape-the-matrix
# 473: permutation-in-string
# 474: maximum-vacation-days
# 475: subtree-of-another-tree
# 476: squirrel-simulation
# 477: distribute-candies
# 478: out-of-boundary-paths
# 479: shortest-unsorted-continuous-subarray
# 480: kill-process
# 481: delete-operation-for-two-strings
# 482: erect-the-fence
# 483: tag-validator
# 484: fraction-addition-and-subtraction
# 485: valid-square
# 486: longest-harmonious-subsequence
# 487: range-addition-ii
# 488: minimum-index-sum-of-two-lists
# 489: non-negative-integers-without-consecutive-ones
# 490: can-place-flowers
# 491: construct-string-from-binary-tree
# 492: find-duplicate-file-in-system
# 493: valid-triangle-number
# 494: add-bold-tag-in-string
# 495: merge-two-binary-trees
# 496: task-scheduler
# 497: add-one-row-to-tree
# 498: maximum-distance-in-arrays
# 499: minimum-factorization
# 500: maximum-product-of-three-numbers
# 501: k-inverse-pairs-array
# 502: course-schedule-iii
# 503: smallest-range-covering-elements-from-k-lists
# 504: sum-of-square-numbers
# 505: find-the-derangement-of-an-array
# 506: exclusive-time-of-functions
# 507: average-of-levels-in-binary-tree
# 508: shopping-offers
# 509: decode-ways-ii
# 510: solve-the-equation
# 511: maximum-average-subarray-i
# 512: maximum-average-subarray-ii
# 513: set-mismatch
# 514: maximum-length-of-pair-chain
# 515: palindromic-substrings
# 516: replace-words
# 517: dota2-senate
# 518: 2-keys-keyboard
# 519: 4-keys-keyboard
# 520: two-sum-iv-input-is-a-bst
# 521: maximum-binary-tree
# 522: print-binary-tree
# 523: coin-path
# 524: robot-return-to-origin
# 525: find-k-closest-elements
# 526: split-array-into-consecutive-subsequences
# 527: remove-9
# 528: image-smoother
# 529: maximum-width-of-binary-tree
# 530: equal-tree-partition
# 531: strange-printer
# 532: non-decreasing-array
# 533: path-sum-iv
# 534: beautiful-arrangement-ii
# 535: kth-smallest-number-in-multiplication-table
# 536: trim-a-binary-search-tree
# 537: maximum-swap
# 538: second-minimum-node-in-a-binary-tree
# 539: bulb-switcher-ii
# 540: number-of-longest-increasing-subsequence
# 541: longest-continuous-increasing-subsequence
# 542: cut-off-trees-for-golf-event
# 543: valid-parenthesis-string
# 544: 24-game
# 545: valid-palindrome-ii
# 546: next-closest-time
# 547: baseball-game
# 548: k-empty-slots
# 549: redundant-connection
# 550: redundant-connection-ii
# 551: repeated-string-match
# 552: longest-univalue-path
# 553: knight-probability-in-chessboard
# 554: maximum-sum-of-3-non-overlapping-subarrays
# 555: stickers-to-spell-word
# 556: top-k-frequent-words
# 557: binary-number-with-alternating-bits
# 558: number-of-distinct-islands
# 559: max-area-of-island
# 560: count-binary-substrings
# 561: degree-of-an-array
# 562: partition-to-k-equal-sum-subsets
# 563: falling-squares
# 564: search-in-a-binary-search-tree
# 565: insert-into-a-binary-search-tree
# 566: binary-search
# 567: to-lower-case
# 568: number-of-distinct-islands-ii
# 569: minimum-ascii-delete-sum-for-two-strings
# 570: subarray-product-less-than-k
# 571: best-time-to-buy-and-sell-stock-with-transaction-fee
# 572: 1-bit-and-2-bit-characters
# 573: maximum-length-of-repeated-subarray
# 574: find-k-th-smallest-pair-distance
# 575: longest-word-in-dictionary
# 576: accounts-merge
# 577: remove-comments
# 578: candy-crush
# 579: find-pivot-index
# 580: number-of-atoms
# 581: minimum-window-subsequence
# 582: self-dividing-numbers
# 583: count-different-palindromic-subsequences
# 584: flood-fill
# 585: sentence-similarity
# 586: asteroid-collision
# 587: parse-lisp-expression
# 588: sentence-similarity-ii
# 589: monotone-increasing-digits
# 590: daily-temperatures
# 591: delete-and-earn
# 592: cherry-pickup
# 593: closest-leaf-in-a-binary-tree
# 594: network-delay-time
# 595: find-smallest-letter-greater-than-target
# 596: min-cost-climbing-stairs
# 597: largest-number-at-least-twice-of-others
# 598: shortest-completing-word
# 599: contain-virus
# 600: number-of-corner-rectangles
# 601: ip-to-cidr
# 602: open-the-lock
# 603: cracking-the-safe
# 604: reach-a-number
# 605: pour-water
# 606: pyramid-transition-matrix
# 607: set-intersection-size-at-least-two
# 608: bold-words-in-string
# 609: find-anagram-mappings
# 610: special-binary-string
# 611: prime-number-of-set-bits-in-binary-representation
# 612: partition-labels
# 613: largest-plus-sign
# 614: couples-holding-hands
# 615: toeplitz-matrix
# 616: reorganize-string
# 617: max-chunks-to-make-sorted-ii
# 618: max-chunks-to-make-sorted
# 619: basic-calculator-iv
# 620: jewels-and-stones
# 621: basic-calculator-iii
# 622: sliding-puzzle
# 623: minimize-max-distance-to-gas-station
# 624: global-and-local-inversions
# 625: swap-adjacent-in-lr-string
# 626: swim-in-rising-water
# 627: k-th-symbol-in-grammar
# 628: reaching-points
# 629: rabbits-in-forest
# 630: transform-to-chessboard
# 631: minimum-distance-between-bst-nodes
# 632: letter-case-permutation
# 633: is-graph-bipartite
# 634: k-th-smallest-prime-fraction
# 635: cheapest-flights-within-k-stops
# 636: rotated-digits
# 637: escape-the-ghosts
# 638: domino-and-tromino-tiling
# 639: custom-sort-string
# 640: number-of-matching-subsequences
# 641: preimage-size-of-factorial-zeroes-function
# 642: valid-tic-tac-toe-state
# 643: number-of-subarrays-with-bounded-maximum
# 644: rotate-string
# 645: all-paths-from-source-to-target
# 646: smallest-rotation-with-highest-score
# 647: champagne-tower
# 648: similar-rgb-color
# 649: minimum-swaps-to-make-sequences-increasing
# 650: find-eventual-safe-states
# 651: bricks-falling-when-hit
# 652: unique-morse-code-words
# 653: split-array-with-same-average
# 654: number-of-lines-to-write-string
# 655: max-increase-to-keep-city-skyline
# 656: soup-servings
# 657: expressive-words
# 658: chalkboard-xor-game
# 659: subdomain-visit-count
# 660: largest-triangle-area
# 661: largest-sum-of-averages
# 662: binary-tree-pruning
# 663: bus-routes
# 664: ambiguous-coordinates
# 665: linked-list-components
# 666: race-car
# 667: short-encoding-of-words
# 668: shortest-distance-to-a-character
# 669: card-flipping-game
# 670: binary-trees-with-factors
# 671: goat-latin
# 672: friends-of-appropriate-ages
# 673: most-profit-assigning-work
# 674: making-a-large-island
# 675: count-unique-characters-of-all-substrings-of-a-given-string
# 676: consecutive-numbers-sum
# 677: positions-of-large-groups
# 678: masking-personal-information
# 679: flipping-an-image
# 680: find-and-replace-in-string
# 681: sum-of-distances-in-tree
# 682: image-overlap
# 683: rectangle-overlap
# 684: new-21-game
# 685: push-dominoes
# 686: similar-string-groups
# 687: magic-squares-in-grid
# 688: keys-and-rooms
# 689: split-array-into-fibonacci-sequence
# 690: backspace-string-compare
# 691: longest-mountain-in-array
# 692: hand-of-straights
# 693: shortest-path-visiting-all-nodes
# 694: shifting-letters
# 695: maximize-distance-to-closest-person
# 696: rectangle-area-ii
# 697: loud-and-rich
# 698: peak-index-in-a-mountain-array
# 699: car-fleet
# 700: k-similar-strings
# 701: score-of-parentheses
# 702: minimum-cost-to-hire-k-workers
# 703: mirror-reflection
# 704: buddy-strings
# 705: lemonade-change
# 706: score-after-flipping-matrix
# 707: shortest-subarray-with-sum-at-least-k
# 708: shortest-path-to-get-all-keys
# 709: smallest-subtree-with-all-the-deepest-nodes
# 710: prime-palindrome
# 711: transpose-matrix
# 712: binary-gap
# 713: reordered-power-of-2
# 714: advantage-shuffle
# 715: minimum-number-of-refueling-stops
# 716: leaf-similar-trees
# 717: length-of-longest-fibonacci-subsequence
# 718: walking-robot-simulation
# 719: koko-eating-bananas
# 720: middle-of-the-linked-list
# 721: stone-game
# 722: nth-magical-number
# 723: profitable-schemes
# 724: decoded-string-at-index
# 725: boats-to-save-people
# 726: reachable-nodes-in-subdivided-graph
# 727: projection-area-of-3d-shapes
# 728: uncommon-words-from-two-sentences
# 729: spiral-matrix-iii
# 730: possible-bipartition
# 731: super-egg-drop
# 732: fair-candy-swap
# 733: construct-binary-tree-from-preorder-and-postorder-traversal
# 734: find-and-replace-pattern
# 735: sum-of-subsequence-widths
# 736: surface-area-of-3d-shapes
# 737: groups-of-special-equivalent-strings
# 738: monotonic-array
# 739: increasing-order-search-tree
# 740: bitwise-ors-of-subarrays
# 741: orderly-queue
# 742: numbers-at-most-n-given-digit-set
# 743: valid-permutations-for-di-sequence
# 744: fruit-into-baskets
# 745: sort-array-by-parity
# 746: super-palindromes
# 747: sum-of-subarray-minimums
# 748: smallest-range-i
# 749: snakes-and-ladders
# 750: smallest-range-ii
# 751: sort-an-array
# 752: cat-and-mouse
# 753: x-of-a-kind-in-a-deck-of-cards
# 754: partition-array-into-disjoint-intervals
# 755: word-subsets
# 756: reverse-only-letters
# 757: maximum-sum-circular-subarray
# 758: number-of-music-playlists
# 759: minimum-add-to-make-parentheses-valid
# 760: sort-array-by-parity-ii
# 761: 3sum-with-multiplicity
# 762: minimize-malware-spread
# 763: long-pressed-name
# 764: flip-string-to-monotone-increasing
# 765: three-equal-parts
# 766: minimize-malware-spread-ii
# 767: unique-email-addresses
# 768: binary-subarrays-with-sum
# 769: minimum-falling-path-sum
# 770: beautiful-array
# 771: shortest-bridge
# 772: knight-dialer
# 773: stamping-the-sequence
# 774: reorder-data-in-log-files
# 775: range-sum-of-bst
# 776: minimum-area-rectangle
# 777: distinct-subsequences-ii
# 778: valid-mountain-array
# 779: di-string-match
# 780: find-the-shortest-superstring
# 781: delete-columns-to-make-sorted
# 782: minimum-increment-to-make-array-unique
# 783: validate-stack-sequences
# 784: most-stones-removed-with-same-row-or-column
# 785: bag-of-tokens
# 786: largest-time-for-given-digits
# 787: reveal-cards-in-increasing-order
# 788: flip-equivalent-binary-trees
# 789: largest-component-size-by-common-factor
# 790: verifying-an-alien-dictionary
# 791: array-of-doubled-pairs
# 792: delete-columns-to-make-sorted-ii
# 793: tallest-billboard
# 794: prison-cells-after-n-days
# 795: check-completeness-of-a-binary-tree
# 796: regions-cut-by-slashes
# 797: delete-columns-to-make-sorted-iii
# 798: n-repeated-element-in-size-2n-array
# 799: maximum-width-ramp
# 800: minimum-area-rectangle-ii
# 801: least-operators-to-express-number
# 802: univalued-binary-tree
# 803: vowel-spellchecker
# 804: numbers-with-same-consecutive-differences
# 805: binary-tree-cameras
# 806: pancake-sorting
# 807: powerful-integers
# 808: flip-binary-tree-to-match-preorder-traversal
# 809: equal-rational-numbers
# 810: k-closest-points-to-origin
# 811: subarray-sums-divisible-by-k
# 812: odd-even-jump
# 813: largest-perimeter-triangle
# 814: squares-of-a-sorted-array
# 815: longest-turbulent-subarray
# 816: distribute-coins-in-binary-tree
# 817: unique-paths-iii
# 818: triples-with-bitwise-and-equal-to-zero
# 819: minimum-cost-for-tickets
# 820: string-without-aaa-or-bbb
# 821: sum-of-even-numbers-after-queries
# 822: interval-list-intersections
# 823: vertical-order-traversal-of-a-binary-tree
# 824: smallest-string-starting-from-leaf
# 825: add-to-array-form-of-integer
# 826: satisfiability-of-equality-equations
# 827: broken-calculator
# 828: subarrays-with-k-different-integers
# 829: cousins-in-binary-tree
# 830: rotting-oranges
# 831: minimum-number-of-k-consecutive-bit-flips
# 832: number-of-squareful-arrays
# 833: find-the-town-judge
# 834: maximum-binary-tree-ii
# 835: available-captures-for-rook
# 836: minimum-cost-to-merge-stones
# 837: grid-illumination
# 838: find-common-characters
# 839: check-if-word-is-valid-after-substitutions
# 840: max-consecutive-ones-iii
# 841: maximize-sum-of-array-after-k-negations
# 842: clumsy-factorial
# 843: minimum-domino-rotations-for-equal-row
# 844: construct-binary-search-tree-from-preorder-traversal
# 845: complement-of-base-10-integer
# 846: pairs-of-songs-with-total-durations-divisible-by-60
# 847: capacity-to-ship-packages-within-d-days
# 848: numbers-with-repeated-digits
# 849: partition-array-into-three-parts-with-equal-sum
# 850: best-sightseeing-pair
# 851: smallest-integer-divisible-by-k
# 852: binary-string-with-substrings-representing-1-to-n
# 853: convert-to-base-2
# 854: binary-prefix-divisible-by-5
# 855: next-greater-node-in-linked-list
# 856: number-of-enclaves
# 857: remove-outermost-parentheses
# 858: sum-of-root-to-leaf-binary-numbers
# 859: camelcase-matching
# 860: video-stitching
# 861: divisor-game
# 862: maximum-difference-between-node-and-ancestor
# 863: longest-arithmetic-subsequence
# 864: recover-a-tree-from-preorder-traversal
# 865: two-city-scheduling
# 866: matrix-cells-in-distance-order
# 867: maximum-sum-of-two-non-overlapping-subarrays
# 868: moving-stones-until-consecutive
# 869: coloring-a-border
# 870: uncrossed-lines
# 871: escape-a-large-maze
# 872: valid-boomerang
# 873: binary-search-tree-to-greater-sum-tree
# 874: minimum-score-triangulation-of-polygon
# 875: moving-stones-until-consecutive-ii
# 876: robot-bounded-in-circle
# 877: flower-planting-with-no-adjacent
# 878: partition-array-for-maximum-sum
# 879: longest-duplicate-substring
# 880: last-stone-weight
# 881: remove-all-adjacent-duplicates-in-string
# 882: longest-string-chain
# 883: last-stone-weight-ii
# 884: height-checker
# 885: grumpy-bookstore-owner
# 886: previous-permutation-with-one-swap
# 887: distant-barcodes
# 888: shortest-way-to-form-string
# 889: confusing-number
# 890: campus-bikes
# 891: minimize-rounding-error-to-meet-target
# 892: all-paths-from-source-lead-to-destination
# 893: missing-element-in-sorted-array
# 894: lexicographically-smallest-equivalent-string
# 895: longest-repeating-substring
# 896: number-of-valid-subarrays
# 897: fixed-point
# 898: index-pairs-of-a-string
# 899: campus-bikes-ii
# 900: digit-count-in-range
# 901: greatest-common-divisor-of-strings
# 902: flip-columns-for-maximum-number-of-equal-rows
# 903: adding-two-negabinary-numbers
# 904: number-of-submatrices-that-sum-to-target
# 905: occurrences-after-bigram
# 906: letter-tile-possibilities
# 907: insufficient-nodes-in-root-to-leaf-paths
# 908: smallest-subsequence-of-distinct-characters
# 909: sum-of-digits-in-the-minimum-number
# 910: high-five
# 911: brace-expansion
# 912: confusing-number-ii
# 913: duplicate-zeros
# 914: largest-values-from-labels
# 915: shortest-path-in-binary-matrix
# 916: shortest-common-supersequence
# 917: statistics-from-a-large-sample
# 918: car-pooling
# 919: brace-expansion-ii
# 920: two-sum-less-than-k
# 921: find-k-length-substrings-with-no-repeated-characters
# 922: the-earliest-moment-when-everyone-become-friends
# 923: path-with-maximum-minimum-value
# 924: distribute-candies-to-people
# 925: path-in-zigzag-labelled-binary-tree
# 926: filling-bookcase-shelves
# 927: parsing-a-boolean-expression
# 928: defanging-an-ip-address
# 929: corporate-flight-bookings
# 930: maximum-nesting-depth-of-two-valid-parentheses-strings
# 931: number-of-days-in-a-month
# 932: remove-vowels-from-a-string
# 933: maximum-average-subtree
# 934: divide-array-into-increasing-sequences
# 935: relative-sort-array
# 936: lowest-common-ancestor-of-deepest-leaves
# 937: longest-well-performing-interval
# 938: smallest-sufficient-team
# 939: number-of-equivalent-domino-pairs
# 940: shortest-path-with-alternating-colors
# 941: minimum-cost-tree-from-leaf-values
# 942: maximum-of-absolute-value-expression
# 943: largest-unique-number
# 944: armstrong-number
# 945: connecting-cities-with-minimum-cost
# 946: parallel-courses
# 947: n-th-tribonacci-number
# 948: alphabet-board-path
# 949: largest-1-bordered-square
# 950: stone-game-ii
# 951: longest-common-subsequence
# 952: decrease-elements-to-make-array-zigzag
# 953: binary-tree-coloring-game
# 954: longest-chunked-palindrome-decomposition
# 955: check-if-a-number-is-majority-element-in-a-sorted-array
# 956: minimum-swaps-to-group-all-1s-together
# 957: analyze-user-website-visit-pattern
# 958: string-transforms-into-another-string
# 959: day-of-the-year
# 960: number-of-dice-rolls-with-target-sum
# 961: swap-for-longest-repeated-character-substring
# 962: find-words-that-can-be-formed-by-characters
# 963: maximum-level-sum-of-a-binary-tree
# 964: as-far-from-land-as-possible
# 965: last-substring-in-lexicographical-order
# 966: single-row-keyboard
# 967: minimum-cost-to-connect-sticks
# 968: optimize-water-distribution-in-a-village
# 969: invalid-transactions
# 970: compare-strings-by-frequency-of-the-smallest-character
# 971: remove-zero-sum-consecutive-nodes-from-linked-list
# 972: prime-arrangements
# 973: diet-plan-performance
# 974: can-make-palindrome-from-substring
# 975: number-of-valid-words-for-each-puzzle
# 976: count-substrings-with-only-one-distinct-letter
# 977: before-and-after-puzzle
# 978: shortest-distance-to-target-color
# 979: maximum-number-of-ones
# 980: distance-between-bus-stops
# 981: day-of-the-week
# 982: maximum-subarray-sum-with-one-deletion
# 983: make-array-strictly-increasing
# 984: maximum-number-of-balloons
# 985: reverse-substrings-between-each-pair-of-parentheses
# 986: k-concatenation-maximum-sum
# 987: critical-connections-in-a-network
# 988: how-many-apples-can-you-put-into-the-basket
# 989: minimum-knight-moves
# 990: find-smallest-common-element-in-all-rows
# 991: minimum-time-to-build-blocks
# 992: minimum-absolute-difference
# 993: ugly-number-iii
# 994: smallest-string-with-swaps
# 995: sort-items-by-groups-respecting-dependencies
# 996: unique-number-of-occurrences
# 997: get-equal-substrings-within-budget
# 998: remove-all-adjacent-duplicates-in-string-ii
# 999: minimum-moves-to-reach-target-with-rotations
# 1000: intersection-of-three-sorted-arrays
# 1001: two-sum-bsts
# 1002: stepping-numbers
# 1003: valid-palindrome-iii
# 1004: minimum-cost-to-move-chips-to-the-same-position
# 1005: longest-arithmetic-subsequence-of-given-difference
# 1006: path-with-maximum-gold
# 1007: count-vowels-permutation
# 1008: split-a-string-in-balanced-strings
# 1009: queens-that-can-attack-the-king
# 1010: dice-roll-simulation
# 1011: maximum-equal-frequency
# 1012: airplane-seat-assignment-probability
# 1013: missing-number-in-arithmetic-progression
# 1014: meeting-scheduler
# 1015: toss-strange-coins
# 1016: divide-chocolate
# 1017: check-if-it-is-a-straight-line
# 1018: remove-sub-folders-from-the-filesystem
# 1019: replace-the-substring-for-balanced-string
# 1020: maximum-profit-in-job-scheduling
# 1021: circular-permutation-in-binary-representation
# 1022: maximum-length-of-a-concatenated-string-with-unique-characters
# 1023: tiling-a-rectangle-with-the-fewest-squares
# 1024: web-crawler-multithreaded
# 1025: array-transformation
# 1026: tree-diameter
# 1027: palindrome-removal
# 1028: minimum-swaps-to-make-strings-equal
# 1029: count-number-of-nice-subarrays
# 1030: minimum-remove-to-make-valid-parentheses
# 1031: check-if-it-is-a-good-array
# 1032: cells-with-odd-values-in-a-matrix
# 1033: reconstruct-a-2-row-binary-matrix
# 1034: number-of-closed-islands
# 1035: maximum-score-words-formed-by-letters
# 1036: encode-number
# 1037: smallest-common-region
# 1038: synonymous-sentences
# 1039: handshakes-that-dont-cross
# 1040: shift-2d-grid
# 1041: greatest-sum-divisible-by-three
# 1042: minimum-moves-to-move-a-box-to-their-target-location
# 1043: minimum-time-visiting-all-points
# 1044: count-servers-that-communicate
# 1045: search-suggestions-system
# 1046: number-of-ways-to-stay-in-the-same-place-after-some-steps
# 1047: hexspeak
# 1048: remove-interval
# 1049: delete-tree-nodes
# 1050: find-winner-on-a-tic-tac-toe-game
# 1051: number-of-burgers-with-no-waste-of-ingredients
# 1052: count-square-submatrices-with-all-ones
# 1053: palindrome-partitioning-iii
# 1054: subtract-the-product-and-sum-of-digits-of-an-integer
# 1055: group-the-people-given-the-group-size-they-belong-to
# 1056: find-the-smallest-divisor-given-a-threshold
# 1057: minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix
# 1058: element-appearing-more-than-25-in-sorted-array
# 1059: remove-covered-intervals
# 1060: minimum-falling-path-sum-ii
# 1061: convert-binary-number-in-a-linked-list-to-integer
# 1062: sequential-digits
# 1063: maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold
# 1064: shortest-path-in-a-grid-with-obstacles-elimination
# 1065: find-numbers-with-even-number-of-digits
# 1066: divide-array-in-sets-of-k-consecutive-numbers
# 1067: maximum-number-of-occurrences-of-a-substring
# 1068: maximum-candies-you-can-get-from-boxes
# 1069: replace-elements-with-greatest-element-on-right-side
# 1070: sum-of-mutated-array-closest-to-target
# 1071: number-of-paths-with-max-score
# 1072: deepest-leaves-sum
# 1073: find-n-unique-integers-sum-up-to-zero
# 1074: all-elements-in-two-binary-search-trees
# 1075: jump-game-iii
# 1076: verbal-arithmetic-puzzle
# 1077: decrypt-string-from-alphabet-to-integer-mapping
# 1078: xor-queries-of-a-subarray
# 1079: get-watched-videos-by-your-friends
# 1080: minimum-insertion-steps-to-make-a-string-palindrome
# 1081: decompress-run-length-encoded-list
# 1082: matrix-block-sum
# 1083: sum-of-nodes-with-even-valued-grandparent
# 1084: distinct-echo-substrings
# 1085: convert-integer-to-the-sum-of-two-no-zero-integers
# 1086: minimum-flips-to-make-a-or-b-equal-to-c
# 1087: number-of-operations-to-make-network-connected
# 1088: minimum-distance-to-type-a-word-using-two-fingers
# 1089: print-words-vertically
# 1090: delete-leaves-with-a-given-value
# 1091: minimum-number-of-taps-to-open-to-water-a-garden
# 1092: break-a-palindrome
# 1093: sort-the-matrix-diagonally
# 1094: reverse-subarray-to-maximize-array-value
# 1095: rank-transform-of-an-array
# 1096: remove-palindromic-subsequences
# 1097: filter-restaurants-by-vegan-friendly-price-and-distance
# 1098: find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance
# 1099: minimum-difficulty-of-a-job-schedule
# 1100: the-k-weakest-rows-in-a-matrix
# 1101: reduce-array-size-to-the-half
# 1102: maximum-product-of-splitted-binary-tree
# 1103: jump-game-v
# 1104: number-of-steps-to-reduce-a-number-to-zero
# 1105: number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold
# 1106: angle-between-hands-of-a-clock
# 1107: jump-game-iv
# 1108: check-if-n-and-its-double-exist
# 1109: minimum-number-of-steps-to-make-two-strings-anagram
# 1110: maximum-students-taking-exam
# 1111: count-negative-numbers-in-a-sorted-matrix
# 1112: maximum-number-of-events-that-can-be-attended
# 1113: construct-target-array-with-multiple-sums
# 1114: sort-integers-by-the-number-of-1-bits
# 1115: number-of-substrings-containing-all-three-characters
# 1116: count-all-valid-pickup-and-delivery-options
# 1117: number-of-days-between-two-dates
# 1118: validate-binary-tree-nodes
# 1119: closest-divisors
# 1120: largest-multiple-of-three
# 1121: how-many-numbers-are-smaller-than-the-current-number
# 1122: rank-teams-by-votes
# 1123: linked-list-in-binary-tree
# 1124: minimum-cost-to-make-at-least-one-valid-path-in-a-grid
# 1125: increasing-decreasing-string
# 1126: find-the-longest-substring-containing-vowels-in-even-counts
# 1127: longest-zigzag-path-in-a-binary-tree
# 1128: maximum-sum-bst-in-binary-tree
# 1129: generate-a-string-with-characters-that-have-odd-counts
# 1130: number-of-times-binary-string-is-prefix-aligned
# 1131: time-needed-to-inform-all-employees
# 1132: frog-position-after-t-seconds
# 1133: find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree
# 1134: lucky-numbers-in-a-matrix
# 1135: balance-a-binary-search-tree
# 1136: maximum-performance-of-a-team
# 1137: find-the-distance-value-between-two-arrays
# 1138: cinema-seat-allocation
# 1139: sort-integers-by-the-power-value
# 1140: pizza-with-3n-slices
# 1141: create-target-array-in-the-given-order
# 1142: four-divisors
# 1143: check-if-there-is-a-valid-path-in-a-grid
# 1144: longest-happy-prefix
# 1145: find-lucky-integer-in-an-array
# 1146: count-number-of-teams
# 1147: find-all-good-strings
# 1148: count-largest-group
# 1149: construct-k-palindrome-strings
# 1150: circle-and-rectangle-overlapping
# 1151: reducing-dishes
# 1152: minimum-subsequence-in-non-increasing-order
# 1153: number-of-steps-to-reduce-a-number-in-binary-representation-to-one
# 1154: longest-happy-string
# 1155: stone-game-iii
# 1156: string-matching-in-an-array
# 1157: queries-on-a-permutation-with-key
# 1158: html-entity-parser
# 1159: number-of-ways-to-paint-n-3-grid
# 1160: minimum-value-to-get-positive-step-by-step-sum
# 1161: find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-k
# 1162: the-k-th-lexicographical-string-of-all-happy-strings-of-length-n
# 1163: restore-the-array
# 1164: reformat-the-string
# 1165: display-table-of-food-orders-in-a-restaurant
# 1166: minimum-number-of-frogs-croaking
# 1167: build-array-where-you-can-find-the-maximum-exactly-k-comparisons
# 1168: maximum-score-after-splitting-a-string
# 1169: maximum-points-you-can-obtain-from-cards
# 1170: diagonal-traverse-ii
# 1171: constrained-subsequence-sum
# 1172: counting-elements
# 1173: perform-string-shifts
# 1174: check-if-a-string-is-a-valid-sequence-from-root-to-leaves-path-in-a-binary-tree
# 1175: kids-with-the-greatest-number-of-candies
# 1176: max-difference-you-can-get-from-changing-an-integer
# 1177: check-if-a-string-can-break-another-string
# 1178: number-of-ways-to-wear-different-hats-to-each-other
# 1179: destination-city
# 1180: check-if-all-1s-are-at-least-length-k-places-away
# 1181: longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit
# 1182: find-the-kth-smallest-sum-of-a-matrix-with-sorted-rows
# 1183: build-an-array-with-stack-operations
# 1184: count-triplets-that-can-form-two-arrays-of-equal-xor
# 1185: number-of-ways-of-cutting-a-pizza
# 1186: consecutive-characters
# 1187: simplified-fractions
# 1188: count-good-nodes-in-binary-tree
# 1189: form-largest-integer-with-digits-that-add-up-to-target
# 1190: number-of-students-doing-homework-at-a-given-time
# 1191: rearrange-words-in-a-sentence
# 1192: people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list
# 1193: maximum-number-of-darts-inside-of-a-circular-dartboard
# 1194: check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence
# 1195: maximum-number-of-vowels-in-a-substring-of-given-length
# 1196: max-dot-product-of-two-subsequences
# 1197: make-two-arrays-equal-by-reversing-subarrays
# 1198: check-if-a-string-contains-all-binary-codes-of-size-k
# 1199: course-schedule-iv
# 1200: cherry-pickup-ii
# 1201: maximum-product-of-two-elements-in-an-array
# 1202: maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts
# 1203: reorder-routes-to-make-all-paths-lead-to-the-city-zero
# 1204: probability-of-a-two-boxes-having-the-same-number-of-distinct-balls
# 1205: find-all-the-lonely-nodes
# 1206: shuffle-the-array
# 1207: the-k-strongest-values-in-an-array
# 1208: paint-house-iii
# 1209: delete-n-nodes-after-m-nodes-of-a-linked-list
# 1210: final-prices-with-a-special-discount-in-a-shop
# 1211: find-two-non-overlapping-sub-arrays-each-with-target-sum
# 1212: allocate-mailboxes
# 1213: running-sum-of-1d-array
# 1214: least-number-of-unique-integers-after-k-removals
# 1215: minimum-number-of-days-to-make-m-bouquets
# 1216: clone-binary-tree-with-random-pointer
# 1217: xor-operation-in-an-array
# 1218: making-file-names-unique
# 1219: avoid-flood-in-the-city
# 1220: find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree
# 1221: average-salary-excluding-the-minimum-and-maximum-salary
# 1222: the-kth-factor-of-n
# 1223: longest-subarray-of-1s-after-deleting-one-element
# 1224: parallel-courses-ii
# 1225: path-crossing
# 1226: check-if-array-pairs-are-divisible-by-k
# 1227: number-of-subsequences-that-satisfy-the-given-sum-condition
# 1228: max-value-of-equation
# 1229: can-make-arithmetic-progression-from-sequence
# 1230: last-moment-before-all-ants-fall-out-of-a-plank
# 1231: count-submatrices-with-all-ones
# 1232: minimum-possible-integer-after-at-most-k-adjacent-swaps-on-digits
# 1233: reformat-date
# 1234: range-sum-of-sorted-subarray-sums
# 1235: minimum-difference-between-largest-and-smallest-value-in-three-moves
# 1236: stone-game-iv
# 1237: number-of-good-pairs
# 1238: number-of-substrings-with-only-1s
# 1239: path-with-maximum-probability
# 1240: best-position-for-a-service-centre
# 1241: water-bottles
# 1242: number-of-nodes-in-the-sub-tree-with-the-same-label
# 1243: maximum-number-of-non-overlapping-substrings
# 1244: find-a-value-of-a-mysterious-function-closest-to-target
# 1245: count-odd-numbers-in-an-interval-range
# 1246: number-of-sub-arrays-with-odd-sum
# 1247: number-of-good-ways-to-split-a-string
# 1248: minimum-number-of-increments-on-subarrays-to-form-a-target-array
# 1249: shuffle-string
# 1250: minimum-suffix-flips
# 1251: number-of-good-leaf-nodes-pairs
# 1252: string-compression-ii
# 1253: count-good-triplets
# 1254: find-the-winner-of-an-array-game
# 1255: minimum-swaps-to-arrange-a-binary-grid
# 1256: get-the-maximum-score
# 1257: kth-missing-positive-number
# 1258: can-convert-string-in-k-moves
# 1259: minimum-insertions-to-balance-a-parentheses-string
# 1260: find-longest-awesome-substring
# 1261: make-the-string-great
# 1262: find-kth-bit-in-nth-binary-string
# 1263: maximum-number-of-non-overlapping-subarrays-with-sum-equals-target
# 1264: minimum-cost-to-cut-a-stick
# 1265: the-most-similar-path-in-a-graph
# 1266: three-consecutive-odds
# 1267: minimum-operations-to-make-array-equal
# 1268: magnetic-force-between-two-balls
# 1269: minimum-number-of-days-to-eat-n-oranges
# 1270: strings-differ-by-one-character
# 1271: thousand-separator
# 1272: minimum-number-of-vertices-to-reach-all-nodes
# 1273: minimum-numbers-of-function-calls-to-make-target-array
# 1274: detect-cycles-in-2d-grid
# 1275: most-visited-sector-in-a-circular-track
# 1276: maximum-number-of-coins-you-can-get
# 1277: find-latest-group-of-size-m
# 1278: stone-game-v
# 1279: put-boxes-into-the-warehouse-i
# 1280: detect-pattern-of-length-m-repeated-k-or-more-times
# 1281: maximum-length-of-subarray-with-positive-product
# 1282: minimum-number-of-days-to-disconnect-island
# 1283: number-of-ways-to-reorder-array-to-get-same-bst
# 1284: matrix-diagonal-sum
# 1285: number-of-ways-to-split-a-string
# 1286: shortest-subarray-to-be-removed-to-make-array-sorted
# 1287: count-all-possible-routes
# 1288: replace-all-s-to-avoid-consecutive-repeating-characters
# 1289: number-of-ways-where-square-of-number-is-equal-to-product-of-two-numbers
# 1290: minimum-time-to-make-rope-colorful
# 1291: remove-max-number-of-edges-to-keep-graph-fully-traversable
# 1292: put-boxes-into-the-warehouse-ii
# 1293: special-positions-in-a-binary-matrix
# 1294: count-unhappy-friends
# 1295: min-cost-to-connect-all-points
# 1296: check-if-string-is-transformable-with-substring-sort-operations
# 1297: sum-of-all-odd-length-subarrays
# 1298: maximum-sum-obtained-of-any-permutation
# 1299: make-sum-divisible-by-p
# 1300: strange-printer-ii
# 1301: rearrange-spaces-between-words
# 1302: split-a-string-into-the-max-number-of-unique-substrings
# 1303: maximum-non-negative-product-in-a-matrix
# 1304: minimum-cost-to-connect-two-groups-of-points
# 1305: crawler-log-folder
# 1306: maximum-profit-of-operating-a-centennial-wheel
# 1307: maximum-number-of-achievable-transfer-requests
# 1308: find-nearest-right-node-in-binary-tree
# 1309: alert-using-same-key-card-three-or-more-times-in-a-one-hour-period
# 1310: find-valid-matrix-given-row-and-column-sums
# 1311: find-servers-that-handled-most-number-of-requests
# 1312: special-array-with-x-elements-greater-than-or-equal-x
# 1313: even-odd-tree
# 1314: maximum-number-of-visible-points
# 1315: minimum-one-bit-operations-to-make-integers-zero
# 1316: maximum-nesting-depth-of-the-parentheses
# 1317: maximal-network-rank
# 1318: split-two-strings-to-make-palindrome
# 1319: count-subtrees-with-max-distance-between-cities
# 1320: mean-of-array-after-removing-some-elements
# 1321: coordinate-with-maximum-network-quality
# 1322: number-of-sets-of-k-non-overlapping-line-segments
# 1323: largest-substring-between-two-equal-characters
# 1324: lexicographically-smallest-string-after-applying-operations
# 1325: best-team-with-no-conflicts
# 1326: graph-connectivity-with-threshold
# 1327: slowest-key
# 1328: arithmetic-subarrays
# 1329: path-with-minimum-effort
# 1330: rank-transform-of-a-matrix
# 1331: sort-array-by-increasing-frequency
# 1332: widest-vertical-area-between-two-points-containing-no-points
# 1333: count-substrings-that-differ-by-one-character
# 1334: number-of-ways-to-form-a-target-string-given-a-dictionary
# 1335: check-array-formation-through-concatenation
# 1336: count-sorted-vowel-strings
# 1337: furthest-building-you-can-reach
# 1338: kth-smallest-instructions
# 1339: lowest-common-ancestor-of-a-binary-tree-ii
# 1340: get-maximum-in-generated-array
# 1341: minimum-deletions-to-make-character-frequencies-unique
# 1342: sell-diminishing-valued-colored-balls
# 1343: create-sorted-array-through-instructions
# 1344: defuse-the-bomb
# 1345: minimum-deletions-to-make-string-balanced
# 1346: minimum-jumps-to-reach-home
# 1347: distribute-repeating-integers
# 1348: determine-if-two-strings-are-close
# 1349: minimum-operations-to-reduce-x-to-zero
# 1350: maximize-grid-happiness
# 1351: check-if-two-string-arrays-are-equivalent
# 1352: smallest-string-with-a-given-numeric-value
# 1353: ways-to-make-a-fair-array
# 1354: minimum-initial-energy-to-finish-tasks
# 1355: maximum-repeating-substring
# 1356: merge-in-between-linked-lists
# 1357: minimum-number-of-removals-to-make-mountain-array
# 1358: richest-customer-wealth
# 1359: find-the-most-competitive-subsequence
# 1360: minimum-moves-to-make-array-complementary
# 1361: minimize-deviation-in-array
# 1362: goal-parser-interpretation
# 1363: max-number-of-k-sum-pairs
# 1364: concatenation-of-consecutive-binary-numbers
# 1365: minimum-incompatibility
# 1366: longest-palindromic-subsequence-ii
# 1367: count-the-number-of-consistent-strings
# 1368: sum-of-absolute-differences-in-a-sorted-array
# 1369: stone-game-vi
# 1370: delivering-boxes-from-storage-to-ports
# 1371: count-of-matches-in-tournament
# 1372: partitioning-into-minimum-number-of-deci-binary-numbers
# 1373: stone-game-vii
# 1374: maximum-height-by-stacking-cuboids
# 1375: count-ways-to-distribute-candies
# 1376: reformat-phone-number
# 1377: maximum-erasure-value
# 1378: jump-game-vi
# 1379: checking-existence-of-edge-length-limited-paths
# 1380: number-of-distinct-substrings-in-a-string
# 1381: number-of-students-unable-to-eat-lunch
# 1382: average-waiting-time
# 1383: maximum-binary-string-after-change
# 1384: minimum-adjacent-swaps-for-k-consecutive-ones
# 1385: determine-if-string-halves-are-alike
# 1386: maximum-number-of-eaten-apples
# 1387: where-will-the-ball-fall
# 1388: maximum-xor-with-an-element-from-array
# 1389: largest-subarray-length-k
# 1390: maximum-units-on-a-truck
# 1391: count-good-meals
# 1392: ways-to-split-array-into-three-subarrays
# 1393: minimum-operations-to-make-a-subsequence
# 1394: sum-of-special-evenly-spaced-elements-in-array
# 1395: calculate-money-in-leetcode-bank
# 1396: maximum-score-from-removing-substrings
# 1397: construct-the-lexicographically-largest-valid-sequence
# 1398: number-of-ways-to-reconstruct-a-tree
# 1399: decode-xored-array
# 1400: swapping-nodes-in-a-linked-list
# 1401: minimize-hamming-distance-after-swap-operations
# 1402: find-minimum-time-to-finish-all-jobs
# 1403: number-of-rectangles-that-can-form-the-largest-square
# 1404: tuple-with-same-product
# 1405: largest-submatrix-with-rearrangements
# 1406: cat-and-mouse-ii
# 1407: shortest-path-to-get-food
# 1408: find-the-highest-altitude
# 1409: minimum-number-of-people-to-teach
# 1410: decode-xored-permutation
# 1411: latest-time-by-replacing-hidden-digits
# 1412: change-minimum-characters-to-satisfy-one-of-three-conditions
# 1413: find-kth-largest-xor-coordinate-value
# 1414: building-boxes
# 1415: find-distance-in-a-binary-tree
# 1416: maximum-number-of-balls-in-a-box
# 1417: restore-the-array-from-adjacent-pairs
# 1418: can-you-eat-your-favorite-candy-on-your-favorite-day
# 1419: palindrome-partitioning-iv
# 1420: maximum-subarray-sum-after-one-operation
# 1421: sum-of-unique-elements
# 1422: maximum-absolute-sum-of-any-subarray
# 1423: minimum-length-of-string-after-deleting-similar-ends
# 1424: maximum-number-of-events-that-can-be-attended-ii
# 1425: check-if-array-is-sorted-and-rotated
# 1426: maximum-score-from-removing-stones
# 1427: largest-merge-of-two-strings
# 1428: closest-subsequence-sum
# 1429: minimum-changes-to-make-alternating-binary-string
# 1430: count-number-of-homogenous-substrings
# 1431: minimum-limit-of-balls-in-a-bag
# 1432: minimum-degree-of-a-connected-trio-in-a-graph
# 1433: buildings-with-an-ocean-view
# 1434: longest-nice-substring
# 1435: form-array-by-concatenating-subarrays-of-another-array
# 1436: map-of-highest-peak
# 1437: tree-of-coprimes
# 1438: merge-strings-alternately
# 1439: minimum-number-of-operations-to-move-all-balls-to-each-box
# 1440: maximum-score-from-performing-multiplication-operations
# ...
# 2292: minimum-time-takes-to-reach-destination-without-drowning
# 2293: max-pair-sum-in-an-array
# 2294: double-a-number-represented-as-a-linked-list
# 2295: minimum-absolute-difference-between-elements-with-constraint
# 2296: minimum-relative-loss-after-buying-chocolates
# 2297: count-pairs-whose-sum-is-less-than-target
# 2298: make-string-a-subsequence-using-cyclic-increments
# 2299: sorting-three-groups
# 2300: number-of-beautiful-integers-in-the-range
# 2301: check-if-a-string-is-an-acronym-of-words
# 2302: determine-the-minimum-sum-of-a-k-avoiding-array
# 2303: maximize-the-profit-as-the-salesman
# 2304: find-the-longest-equal-subarray
# 2305: maximal-range-that-each-element-is-maximum-in-it
# 2306: furthest-point-from-origin
# 2307: find-the-minimum-possible-sum-of-a-beautiful-array
# 2308: minimum-operations-to-form-subsequence-with-target-sum
# 2309: maximize-value-of-function-in-a-ball-passing-game
# 2310: maximum-coins-heroes-can-collect
# 2311: check-if-strings-can-be-made-equal-with-operations-i
# 2312: check-if-strings-can-be-made-equal-with-operations-ii
# 2313: maximum-sum-of-almost-unique-subarray
# 2314: count-k-subsequences-of-a-string-with-maximum-beauty
# 2315: count-symmetric-integers
# 2316: minimum-operations-to-make-a-special-number
# 2317: count-of-interesting-subarrays
# 2318: minimum-edge-weight-equilibrium-queries-in-a-tree
# 2319: smallest-number-with-given-digit-product
# 2320: points-that-intersect-with-cars
# 2321: determine-if-a-cell-is-reachable-at-a-given-time
# 2322: minimum-moves-to-spread-stones-over-grid
# 2323: string-transformation
# 2324: sum-of-remoteness-of-all-cells
# 2325: minimum-right-shifts-to-sort-the-array
# 2326: minimum-array-length-after-pair-removals
# 2327: count-pairs-of-points-with-distance-k
# 2328: minimum-edge-reversals-so-every-node-is-reachable
# 2329: sum-of-values-at-indices-with-k-set-bits
# 2330: happy-students
# 2331: maximum-number-of-alloys
# 2332: maximum-element-sum-of-a-complete-subset-of-indices
# 2333: maximum-length-of-semi-decreasing-subarrays
# 2334: maximum-odd-binary-number
# 2335: beautiful-towers-i
# 2336: beautiful-towers-ii
# 2337: count-valid-paths-in-a-tree
# 2338: the-wording-game
# 2339: minimum-operations-to-collect-elements
# 2340: minimum-number-of-operations-to-make-array-empty
# 2341: split-array-into-maximum-number-of-subarrays
# 2342: maximum-number-of-k-divisible-components
# 2343: maximum-value-of-an-ordered-triplet-i
# 2344: maximum-value-of-an-ordered-triplet-ii
# 2345: minimum-size-subarray-in-infinite-array
# 2346: count-visited-nodes-in-a-directed-graph
# 2347: minimizing-array-after-replacing-pairs-with-their-product
# 2348: divisible-and-non-divisible-sums-difference
# 2349: minimum-processing-time
# 2350: apply-operations-to-make-two-strings-equal
# 2351: apply-operations-on-array-to-maximize-sum-of-squares
# 2352: maximum-linear-stock-score
# 2353: last-visited-integers
# 2354: longest-unequal-adjacent-groups-subsequence-i
# 2355: longest-unequal-adjacent-groups-subsequence-ii
# 2356: count-of-sub-multisets-with-bounded-sum
# 2357: find-indices-with-index-and-value-difference-i
# 2358: shortest-and-lexicographically-smallest-beautiful-string
# 2359: find-indices-with-index-and-value-difference-ii
# 2360: construct-product-matrix
# 2361: maximum-profitable-triplets-with-increasing-prices-i
# 2362: minimum-sum-of-mountain-triplets-i
# 2363: minimum-sum-of-mountain-triplets-ii
# 2364: minimum-changes-to-make-k-semi-palindromes
# 2365: number-of-ways-to-reach-destination-in-the-grid
# 2366: subarrays-distinct-element-sum-of-squares-i
# 2367: minimum-number-of-changes-to-make-binary-string-beautiful
# 2368: length-of-the-longest-subsequence-that-sums-to-target
# 2369: subarrays-distinct-element-sum-of-squares-ii
# 2370: find-the-k-or-of-an-array
# 2371: minimum-equal-sum-of-two-arrays-after-replacing-zeros
# 2372: minimum-increment-operations-to-make-array-beautiful
# 2373: maximum-points-after-collecting-coins-from-all-nodes
# 2374: maximum-profitable-triplets-with-increasing-prices-ii
# 2375: find-champion-i
# 2376: find-champion-ii
# 2377: maximum-score-after-applying-operations-on-a-tree
# 2378: maximum-balanced-subsequence-sum
# 2379: distribute-candies-among-children-iii
# 2380: distribute-candies-among-children-i
# 2381: distribute-candies-among-children-ii
# 2382: number-of-strings-which-can-be-rearranged-to-contain-substring
# 2383: maximum-spending-after-buying-items
# 2384: maximum-strong-pair-xor-i
# 2385: high-access-employees
# 2386: minimum-operations-to-maximize-last-elements-in-arrays
# 2387: maximum-strong-pair-xor-ii
# 2388: make-three-strings-equal
# 2389: separate-black-and-white-balls
# 2390: maximum-xor-product
# 2391: find-building-where-alice-and-bob-can-meet
# 2392: maximum-gcd-sum-of-a-subarray
# 2393: find-words-containing-character
# 2394: maximize-area-of-square-hole-in-grid
# 2395: minimum-number-of-coins-for-fruits
# 2396: find-maximum-non-decreasing-array-length
# 2397: matrix-similarity-after-cyclic-shifts
# 2398: count-beautiful-substrings-i
# 2399: make-lexicographically-smallest-array-by-swapping-elements
# 2400: count-beautiful-substrings-ii
# 2401: number-of-divisible-substrings
# 2402: find-the-peaks
# 2403: minimum-number-of-coins-to-be-added
# 2404: count-complete-substrings
# 2405: number-of-same-end-substrings
# 2406: find-common-elements-between-two-arrays
# 2407: remove-adjacent-almost-equal-characters
# 2408: length-of-longest-subarray-with-at-most-k-frequency
# 2409: number-of-possible-sets-of-closing-branches
# 2410: count-tested-devices-after-test-operations
# 2411: count-subarrays-where-max-element-appears-at-least-k-times
# 2412: number-of-divisible-triplet-sums
# 2413: find-missing-and-repeated-values
# 2414: divide-array-into-arrays-with-max-difference
# 2415: minimum-cost-to-make-array-equalindromic
# 2416: apply-operations-to-maximize-frequency-score
# 2417: minimum-number-of-coins-for-fruits-ii
# 2418: count-the-number-of-incremovable-subarrays-i
# 2419: find-polygon-with-the-largest-perimeter
# 2420: count-the-number-of-incremovable-subarrays-ii
# 2421: find-number-of-coins-to-place-in-tree-nodes
# 2422: minimum-number-game
# 2423: maximum-square-area-by-removing-fences-from-a-field
# 2424: minimum-cost-to-convert-string-i
# 2425: minimum-cost-to-convert-string-ii
# 2426: most-expensive-item-that-can-not-be-bought
# 2427: check-if-bitwise-or-has-trailing-zeros
# 2428: find-longest-special-substring-that-occurs-thrice-i
# 2429: find-longest-special-substring-that-occurs-thrice-ii
# 2430: palindrome-rearrangement-queries
# 2431: number-of-self-divisible-permutations
# 2432: smallest-missing-integer-greater-than-sequential-prefix-sum
# 2433: minimum-number-of-operations-to-make-array-xor-equal-to-k
# 2434: minimum-number-of-operations-to-make-x-and-y-equal
# 2435: count-the-number-of-powerful-integers
# 2436: maximum-area-of-longest-diagonal-rectangle
# 2437: minimum-moves-to-capture-the-queen
# 2438: maximum-size-of-a-set-after-removals
# 2439: maximize-the-number-of-partitions-after-operations
# 2440: maximum-subtree-of-the-same-color
# 2441: count-elements-with-maximum-frequency
# 2442: find-beautiful-indices-in-the-given-array-i
# 2443: maximum-number-that-sum-of-the-prices-is-less-than-or-equal-to-k
# 2444: find-beautiful-indices-in-the-given-array-ii
# 2445: maximum-number-of-intersections-on-the-chart
# 2446: divide-an-array-into-subarrays-with-minimum-cost-i
# 2447: find-if-array-can-be-sorted
# 2448: minimize-length-of-array-using-operations
# 2449: divide-an-array-into-subarrays-with-minimum-cost-ii
# 2450: minimum-number-of-pushes-to-type-word-i
# 2451: count-the-number-of-houses-at-a-certain-distance-i
# 2452: minimum-number-of-pushes-to-type-word-ii
# 2453: count-the-number-of-houses-at-a-certain-distance-ii
# 2454: maximum-number-of-removal-queries-that-can-be-processed-i
# 2455: number-of-changing-keys
# 2456: find-the-maximum-number-of-elements-in-subset
# 2457: alice-and-bob-playing-flower-game
# 2458: minimize-or-of-remaining-elements-using-operations
# 2459: type-of-triangle
# 2460: find-the-number-of-ways-to-place-people-i
# 2461: maximum-good-subarray-sum
# 2462: find-the-number-of-ways-to-place-people-ii
# 2463: ant-on-the-boundary
# 2464: minimum-time-to-revert-word-to-initial-state-i
# 2465: find-the-grid-of-region-average
# 2466: minimum-time-to-revert-word-to-initial-state-ii
# 2467: count-numbers-with-unique-digits-ii
# 2468: modify-the-matrix
# 2469: number-of-subarrays-that-match-a-pattern-i
# 2470: maximum-palindromes-after-operations
# 2471: number-of-subarrays-that-match-a-pattern-ii
# 2472: maximum-number-of-operations-with-the-same-score-i
# 2473: apply-operations-to-make-string-empty
# 2474: maximum-number-of-operations-with-the-same-score-ii
# 2475: maximize-consecutive-elements-in-an-array-after-modification
# 2476: count-prefix-and-suffix-pairs-i
# 2477: find-the-length-of-the-longest-common-prefix
# 2478: most-frequent-prime
# 2479: count-prefix-and-suffix-pairs-ii
# 2480: split-the-array
# 2481: find-the-largest-area-of-square-inside-two-rectangles
# 2482: earliest-second-to-mark-indices-i
# 2483: winner-of-the-linked-list-game
# 2484: linked-list-frequency
# 2485: minimum-operations-to-exceed-threshold-value-i
# 2486: minimum-operations-to-exceed-threshold-value-ii
# 2487: count-pairs-of-connectable-servers-in-a-weighted-tree-network
# 2488: find-the-maximum-sum-of-node-values
# 2489: distribute-elements-into-two-arrays-i
# 2490: count-submatrices-with-top-left-element-and-sum-less-than-k
# 2491: minimum-operations-to-write-the-letter-y-on-a-grid
# 2492: distribute-elements-into-two-arrays-ii
# 2493: maximum-increasing-triplet-value
# 2494: apple-redistribution-into-boxes
# 2495: maximize-happiness-of-selected-children
# 2496: shortest-uncommon-substring-in-an-array
# 2497: maximum-strength-of-k-disjoint-subarrays
# 2498: match-alphanumerical-pattern-in-matrix-i
# 2499: find-the-sum-of-encrypted-integers
# 2500: mark-elements-on-array-by-performing-queries
# 2501: replace-question-marks-in-string-to-minimize-its-value
# 2502: find-the-sum-of-the-power-of-all-subsequences
# 2503: existence-of-a-substring-in-a-string-and-its-reverse
# 2504: count-substrings-starting-and-ending-with-given-character
# 2505: minimum-deletions-to-make-string-k-special
# 2506: minimum-moves-to-pick-k-ones
# 2507: make-string-anti-palindrome
# 2508: maximum-length-substring-with-two-occurrences
# 2509: apply-operations-to-make-sum-of-array-greater-than-or-equal-to-k
# 2510: most-frequent-ids
# 2511: longest-common-suffix-queries
# 2512: shortest-subarray-with-or-at-least-k-i
# 2513: minimum-levels-to-gain-more-points
# 2514: shortest-subarray-with-or-at-least-k-ii
# 2515: find-the-sum-of-subsequence-powers
# 2516: harshad-number
# 2517: water-bottles-ii
# 2518: count-alternating-subarrays
# 2519: minimize-manhattan-distances
# 2520: find-longest-self-contained-substring
# 2521: longest-strictly-increasing-or-strictly-decreasing-subarray
# 2522: lexicographically-smallest-string-after-operations-with-constraint
# 2523: minimum-operations-to-make-median-of-array-equal-to-k
# 2524: minimum-cost-walk-in-weighted-graph
# 2525: find-the-index-of-permutation
# 2526: score-of-a-string
# 2527: minimum-rectangles-to-cover-points
# 2528: minimum-time-to-visit-disappearing-nodes
# 2529: find-the-number-of-subarrays-where-boundary-elements-are-maximum
# 2530: latest-time-you-can-obtain-after-replacing-characters
# 2531: maximum-prime-difference
# 2532: kth-smallest-amount-with-single-denomination-combination
# 2533: minimum-sum-of-values-by-dividing-array
# 2534: maximum-number-of-potholes-that-can-be-fixed
# 2535: count-the-number-of-special-characters-i
# 2536: count-the-number-of-special-characters-ii
# 2537: minimum-number-of-operations-to-satisfy-conditions
# 2538: find-edges-in-shortest-paths
# 2539: maximum-number-that-makes-result-of-bitwise-and-zero
# 2540: make-a-square-with-the-same-color
# 2541: right-triangles
# 2542: find-all-possible-stable-binary-arrays-i
# 2543: find-all-possible-stable-binary-arrays-ii
# 2544: find-the-integer-added-to-array-i
# 2545: find-the-integer-added-to-array-ii
# 2546: minimum-array-end
# 2547: find-the-median-of-the-uniqueness-array
# 2548: equalize-strings-by-adding-or-removing-characters-at-ends
# 2549: valid-word
# 2550: minimum-number-of-operations-to-make-word-k-periodic
# 2551: minimum-length-of-anagram-concatenation
# 2552: minimum-cost-to-equalize-array
# 2553: maximum-hamming-distances
# 2554: check-if-grid-satisfies-conditions
# 2555: maximum-points-inside-the-square
# 2556: minimum-substring-partition-of-equal-character-frequency
# 2557: permutation-difference-between-two-strings
# 2558: taking-maximum-energy-from-the-mystic-dungeon
# 2559: maximum-difference-score-in-a-grid
# 2560: find-the-minimum-cost-array-permutation
# 2561: special-array-i
# 2562: special-array-ii
# 2563: sum-of-digit-differences-of-all-pairs
# 2564: find-number-of-ways-to-reach-the-k-th-stair
# 2565: maximum-number-of-upgradable-servers
# 2566: find-the-level-of-tree-with-minimum-sum
# 2567: find-the-xor-of-numbers-which-appear-twice
# 2568: find-occurrences-of-an-element-in-an-array
# 2569: find-the-number-of-distinct-colors-among-the-balls
# 2570: block-placement-queries
# 2571: find-the-number-of-good-pairs-i
# 2572: string-compression-iii
# 2573: find-the-number-of-good-pairs-ii
# 2574: maximum-sum-of-subsequence-with-non-adjacent-elements
# 2575: better-compression-of-string
# 2576: minimum-number-of-chairs-in-a-waiting-room
# 2577: count-days-without-meetings
# 2578: lexicographically-minimum-string-after-removing-stars
# 2579: find-subarray-with-bitwise-or-closest-to-k
# 2580: bitwise-or-of-adjacent-elements
# 2581: clear-digits
# 2582: find-the-first-player-to-win-k-games-in-a-row
# 2583: find-the-maximum-length-of-a-good-subsequence-i
# 2584: find-the-maximum-length-of-a-good-subsequence-ii
# 2585: find-the-child-who-has-the-ball-after-k-seconds
# 2586: find-the-n-th-value-after-k-seconds
# 2587: maximum-total-reward-using-operations-i
# 2588: maximum-total-reward-using-operations-ii
# 2589: the-number-of-ways-to-make-the-sum
# 2590: count-pairs-that-form-a-complete-day-i
# 2591: count-pairs-that-form-a-complete-day-ii
# 2592: maximum-total-damage-with-spell-casting
# 2593: peaks-in-array
# 2594: minimum-moves-to-get-a-peaceful-board
# 2595: find-minimum-operations-to-make-all-elements-divisible-by-three
# 2596: minimum-operations-to-make-binary-array-elements-equal-to-one-i
# 2597: minimum-operations-to-make-binary-array-elements-equal-to-one-ii
# 2598: count-the-number-of-inversions
# 2599: minimum-average-of-smallest-and-largest-elements
# 2600: find-the-minimum-area-to-cover-all-ones-i
# 2601: maximize-total-cost-of-alternating-subarrays
# 2602: find-the-minimum-area-to-cover-all-ones-ii
# 2603: count-triplets-with-even-xor-set-bits-i
# 2604: maximum-height-of-a-triangle
# 2605: find-the-maximum-length-of-valid-subsequence-i
# 2606: find-the-maximum-length-of-valid-subsequence-ii
# 2607: find-minimum-diameter-after-merging-two-trees
# 2608: maximum-array-hopping-score-i
# 2609: alternating-groups-i
# 2610: maximum-points-after-enemy-battles
# 2611: alternating-groups-ii
# 2612: number-of-subarrays-with-and-value-of-k
# 2613: find-the-encrypted-string
# 2614: generate-binary-strings-without-adjacent-zeros
# 2615: count-submatrices-with-equal-frequency-of-x-and-y
# 2616: construct-string-with-minimum-cost
# 2617: count-triplets-with-even-xor-set-bits-ii
# 2618: lexicographically-smallest-string-after-a-swap
# 2619: delete-nodes-from-linked-list-present-in-array
# 2620: minimum-cost-for-cutting-cake-i
# 2621: minimum-cost-for-cutting-cake-ii
# 2622: maximum-array-hopping-score-ii
# 2623: find-the-winning-player-in-coin-game
# 2624: minimum-length-of-string-after-operations
# 2625: minimum-array-changes-to-make-differences-equal
# 2626: maximum-score-from-grid-operations
# 2627: number-of-bit-changes-to-make-two-integers-equal
# 2628: vowels-game-in-a-string
# 2629: maximum-number-of-operations-to-move-ones-to-the-end
# 2630: minimum-operations-to-make-array-equal-to-target
# 2631: minimum-number-of-increasing-subsequence-to-be-removed
# 2632: find-if-digit-game-can-be-won
# 2633: find-the-count-of-numbers-which-are-not-special
# 2634: count-the-number-of-substrings-with-dominant-ones
# 2635: check-if-the-rectangle-corner-is-reachable
# 2636: alt-and-tab-simulation
# 2637: find-the-number-of-winning-players
# 2638: minimum-number-of-flips-to-make-binary-grid-palindromic-i
# 2639: minimum-number-of-flips-to-make-binary-grid-palindromic-ii
# 2640: time-taken-to-mark-all-nodes
# []
